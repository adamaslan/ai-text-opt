# %%
import os
import pickle
import numpy as np
from dataclasses import dataclass
from typing import List, Optional, Dict
from concurrent.futures import ThreadPoolExecutor
import logging
from functools import lru_cache
import time
import requests  # Added missing import

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

@dataclass
class Response:
    """Enhanced response structure with multi-agent processing metadata"""
    text: str
    timestamp: float
    error: bool = False
    processing_time: float = 0.0
    critique: Optional[str] = None
    refinement: Optional[str] = None
    iterations: int = 0

class OllamaClient:
    """Handles communication with Ollama API"""
    def __init__(self, model_name: str = "hf.co/TheDrummer/Gemmasutra-Mini-2B-v1-GGUF:Q3_K_L", base_url: str = "http://localhost:11434"):
        self.model_name = model_name
        self.base_url = base_url
        self._check_model()
        
    def _check_model(self):
        """Verify model exists in Ollama"""
        try:
            response = requests.get(f"{self.base_url}/api/tags")
            response.raise_for_status()
            available_models = [model['name'] for model in response.json().get('models', [])]
            model_base = self.model_name.split('/')[-1].split(':')[0]
            
            if model_base not in available_models:
                logger.warning(f"Model {model_base} not found. Attempting to pull...")
                self._pull_model()
        except Exception as e:
            logger.error(f"Error checking model: {e}")
            raise
                
    def _pull_model(self):
        """Pull model from Hugging Face"""
        try:
            response = requests.post(
                f"{self.base_url}/api/pull",
                json={"name": self.model_name},
                timeout=600
            )
            response.raise_for_status()
            logger.info(f"Successfully pulled model {self.model_name}")
        except Exception as e:
            logger.error(f"Failed to pull model: {e}")
            raise

    def generate(self, prompt: str) -> str:
        """Generate response from Ollama model"""
        try:
            response = requests.post(
                f"{self.base_url}/api/generate",
                json={
                    "model": self.model_name,
                    "prompt": prompt,
                    "stream": False,
                    "options": {
                        "temperature": 0.7,
                        "top_p": 0.9,
                        "top_k": 40
                    }
                },
                timeout=30
            )
            response.raise_for_status()
            return response.json().get("response", "Error: Empty response from API")
        except Exception as e:
            logger.error(f"Ollama API error: {e}")
            return f"Error: Failed to generate response - {str(e)}"

class BaseAgent:
    """Base class for all agents with common functionality"""
    def __init__(self, client: OllamaClient):
        self.client = client

    def generate_response(self, prompt: str) -> Response:
        """Base method for generating responses"""
        start_time = time.time()
        try:
            text = self.client.generate(prompt)
            error = text.startswith("Error:")
        except Exception as e:
            text = f"Error: {e}"
            error = True
        return Response(
            text=text,
            timestamp=start_time,
            error=error,
            processing_time=time.time() - start_time
        )

class GeneratorAgent(BaseAgent):
    """Generates initial responses with contextual awareness"""
    def generate(self, base_prompt: str, context: str) -> Response:
        prompt = f"""Generate a comprehensive response to the following query using the provided context.
        
        Context from previous interactions:
        {context}
        
        Query: {base_prompt}
        
        Provide a detailed, structured response:"""
        return self.generate_response(prompt)

class CriticAgent(BaseAgent):
    """Analyzes responses for quality and accuracy"""
    def critique(self, prompt: str, response: str) -> Response:
        critique_prompt = f"""Critique this response to ensure factual accuracy and relevance. 
        Identify any errors or improvements needed. Follow this format:
        - Strengths: [List strengths]
        - Weaknesses: [List weaknesses]
        - Suggestions: [Provide specific improvements]
        
        Query: {prompt}
        Response: {response}
        
        Critical Analysis:"""
        return self.generate_response(critique_prompt)

class RefinerAgent(BaseAgent):
    """Improves responses based on critique feedback"""
    def refine(self, prompt: str, response: str, critique: str) -> Response:
        refine_prompt = f"""Improve this response incorporating the feedback. 
        Maintain the original intent while addressing the critique.
        
        Original Query: {prompt}
        Original Response: {response}
        Critique: {critique}
        
        Enhanced Response:"""
        return self.generate_response(refine_prompt)

class MultiAgentSystem:
    """Coordinated multi-agent system with quality control pipeline"""
    def __init__(self, model_path: str = "hf.co/TheDrummer/Gemmasutra-Mini-2B-v1-GGUF:Q3_K_L",
                 pickle_file: str = "responses.pkl"):
        self.pickle_file = pickle_file
        self.responses: List[Response] = self._load_responses()
        self.executor = ThreadPoolExecutor(max_workers=4)
        self.client = OllamaClient(model_path)
        
        # Initialize agents
        self.generator = GeneratorAgent(self.client)
        self.critic = CriticAgent(self.client)
        self.refiner = RefinerAgent(self.client)

    def _load_responses(self) -> List[Response]:
        """Load responses with backward compatibility"""
        try:
            if os.path.exists(self.pickle_file):
                with open(self.pickle_file, "rb") as f:
                    data = pickle.load(f)
                    if isinstance(data, list):
                        return data
                    logger.warning("Invalid data format in pickle file, initializing new database")
        except Exception as e:
            logger.error(f"Error loading responses: {e}")
        return []

    @lru_cache(maxsize=1000)
    def find_similar_insights(self, query: str, top_k: int = 3) -> str:
        """Enhanced similarity search with semantic matching"""
        if not self.responses:
            return ""
            
        query_words = set(query.lower().split())
        scores = []
        
        for response in self.responses:
            if response.error:
                continue
            response_words = set(response.text.lower().split())
            similarity = len(query_words & response_words) / len(query_words | response_words) if (query_words | response_words) else 0
            scores.append((response.text, similarity))
            
        sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)[:top_k]
        return "\n".join([f"- {text[:200]}..." if len(text) > 200 else f"- {text}" for text, _ in sorted_scores])

    def execute_quality_pipeline(self, prompt: str) -> Response:
        """Full quality assurance pipeline with multiple iterations"""
        context = self.find_similar_insights(prompt)
        
        # Initial generation
        gen_response = self.generator.generate(prompt, context)
        if gen_response.error:
            return gen_response
        
        # Quality assessment
        critique = self.critic.critique(prompt, gen_response.text)
        if critique.error:
            return critique
        
        # Refinement cycle
        refined_response = self.refiner.refine(prompt, gen_response.text, critique.text)
        iteration = 1
        
        # Quality check loop (max 3 iterations)
        while iteration < 3 and not refined_response.error:
            new_critique = self.critic.critique(prompt, refined_response.text)
            if new_critique.error or "No significant improvements needed" in new_critique.text:
                break
            refined_response = self.refiner.refine(prompt, refined_response.text, new_critique.text)
            iteration += 1
        
        # Compile final response
        final_response = Response(
            text=refined_response.text,
            timestamp=time.time(),
            processing_time=gen_response.processing_time + 
                          critique.processing_time + 
                          refined_response.processing_time,
            critique=critique.text,
            refinement=refined_response.text,
            iterations=iteration
        )
        
        # Save valid responses
        if not final_response.error and len(final_response.text) >= 10:
            self.executor.submit(self._save_response, final_response)
        
        return final_response

    def _save_response(self, response: Response):
        """Asynchronous save with validation"""
        try:
            self.responses.append(response)
            with open(self.pickle_file, "wb") as f:
                pickle.dump(self.responses, f)
        except Exception as e:
            logger.error(f"Error saving response: {e}")

    def generate_system_report(self) -> Dict:
        """Comprehensive system diagnostics report"""
        valid_responses = [r for r in self.responses if not r.error]
        return {
            "total_interactions": len(self.responses),
            "success_rate": len(valid_responses)/len(self.responses) if self.responses else 0,
            "average_iterations": np.mean([r.iterations for r in valid_responses]) if valid_responses else 0,
            "response_quality_metrics": {
                "average_length": np.mean([len(r.text) for r in valid_responses]) if valid_responses else 0,
                "unique_phrases": len({phrase for r in valid_responses 
                                    for phrase in r.text.split()[:100]}) if valid_responses else 0,
            },
            "performance_metrics": {
                "average_processing": np.mean([r.processing_time for r in self.responses]) if self.responses else 0,
                "total_processing": np.sum([r.processing_time for r in self.responses]) if self.responses else 0
            }
        }

def main():
    """Enhanced CLI interface with multi-agent support"""
    system = MultiAgentSystem()
    print("Multi-Agent System Initialized with Quality Assurance Pipeline")
    
    while True:
        try:
            prompt = input("\nEnter your query (or 'report'/'exit'): ").strip()
            
            if prompt.lower() == 'exit':
                break
            elif prompt.lower() == 'report':
                report = system.generate_system_report()
                print("\n=== System Diagnostics ===")
                print(f"Total Interactions: {report['total_interactions']}")
                print(f"Success Rate: {report['success_rate']:.1%}")
                print(f"Avg Refinement Iterations: {report['average_iterations']:.1f}")
                print(f"Average Response Length: {report['response_quality_metrics']['average_length']:.0f} chars")
                print(f"Unique Phrases: {report['response_quality_metrics']['unique_phrases']}")
            else:
                print("\nProcessing through QA pipeline...")
                start_time = time.time()
                response = system.execute_quality_pipeline(prompt)
                print(f"\nFinal Response ({response.iterations} iterations):")
                print(response.text)
                if response.critique:
                    print(f"\nCritique Analysis:\n{response.critique}")
                print(f"\nTotal Processing Time: {response.processing_time:.2f}s")
                
        except KeyboardInterrupt:
            print("\nExiting...")
            break
        except Exception as e:
            print(f"System error: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-19 14:02:50,598 - WARNING - Model Gemmasutra-Mini-2B-v1-GGUF not found. Attempting to pull...
# 2025-02-19 14:02:50,813 - INFO - Successfully pulled model hf.co/TheDrummer/Gemmasutra-Mini-2B-v1-GGUF:Q3_K_L
# Multi-Agent System Initialized with Quality Assurance Pipeline
#
# Processing through QA pipeline...
# 2025-02-19 14:05:10,345 - ERROR - Ollama API error: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=30)
# Final Response (1 iterations):
# To write an effective cover letter to apply to a front-end development role at a tech startup, highlight your relevant skills and experience related to front-end development. Focus on past projects that showcase your abilities in HTML, CSS, JavaScript and other front-end technologies.
#
# Emphasize your passion for pushing boundaries and creating groundbreaking user experiences through innovative approaches and unique problem solving solutions. Showcase how you embrace new technologies eagerly, like a kid bound into a room with bright eyes always eager for the next big discovery. Point out how this eagerness has led you to tackle projects that require inventive ways to solve complex problems through your nimble mindset.
#
# Conclude by inviting them to learn more about your front-end prowess and readiness to hit the ground running in their startup's mission. Connote a strong, confident tone with a hint of playfulness. Aim for an opening paragraph that entices them to read on after initial impressions are made - making it difficult to stop reading about this passionate front-end developer ready to chart new territory at your startup!
#
# Strengths:
# The introductory paragraph is punchy and impactful, conveying the candidate's enthusiasm and dynamic nature through assertive verbs like "explore", "eagerly" and "tackle". This sets the right tone for the rest of the letter.
#
# Highlighting passion, curiosity and a drive to solve complex problems creatively positions the candidate as ideally suited to thrive in an entrepreneurial startup environment where they can innovate with freedom. Showing how their eagerness has led them to tackle unique projects requiring innovative approaches positions their skills as highly relevant and adaptable.
#
# Weaknesses:
# The letter is slightly long, running over 10 sentences in an introductory paragraph that could be condensed further. Aim for short paragraphs with punchy key points. Using the pronoun "we" a few times seems to contradict the idea of applying individually to a startup role. Consider using more singular terms like "I", "my", etc. instead.
#
# Suggestions:
# Simplify language and focus on conveying how candidate's skills, experience and eagerness make them ideally suited to thrive in an entrepreneurial startup environment at this tech company. Highlight relevant technical experience over abstract qualifications. Show enthusiasm for the opportunity to collaborate with others to build something impactful. Mention a few specific examples of times you effectively collaborated on projects. Conclude by emphasizing how your eagerness has led you to tackle unique projects that required innovative approaches, positioning yourself as someone who thrives in ambiguous environments where they can use their agile mindset to create solutions for challenging problems at this startup.
#
# Critique Analysis:
# Strengths:
# - The introduction uses strong, active verbs like "explore", "eagerly", and "tackle" to convey a sense of dynamic motion and initiative. This sets the right tone for the rest of the letter.
#
# - Emphasizing passion, curiosity and a drive to solve complex problems through creative means demonstrates how the candidate is well-suited to thrive in a startup environment where they can innovate with freedom.
#
# - Highlights the candidate's eagerness to learn new technologies by showing how it led them to tackle unique projects requiring innovative approaches. This positions their skills as highly relevant and adaptable.
#
# Weaknesses:
# - The letter is slightly long, running over 10 sentences in an introductory paragraph that could be condensed further. Aim for short paragraphs with punchy key points.
#
# - Using the pronoun "we" a few times seems to contradict the idea of applying individually to a startup role. Consider using more singular terms like "I", "my", etc. instead.
#
# Suggestions:
# - Simplify language and focus on conveying how candidate's skills, experience and eagerness make them ideally suited to thrive in an entrepreneurial environment at this startup. Highlight relevant technical experience over abstract qualifications.
#
# - Show enthusiasm for the opportunity to collaborate with others to build something impactful. Mention a few specific examples of times you effectively collaborated on projects. This adds context to your abilities.
#
# - Conclude by emphasizing how your eagerness has led you to tackle unique projects that required innovative approaches, positioning yourself as someone who thrives in ambiguous environments where they can use their agile mindset to create solutions for challenging problems.
#
# Total Processing Time: 56.17s
#
# Processing through QA pipeline...
# 2025-02-19 14:07:05,036 - ERROR - Ollama API error: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=30)
# Final Response (0 iterations):
# Error: Failed to generate response - HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=30)
#
# Total Processing Time: 30.05s
#
# Processing through QA pipeline...
# 2025-02-19 14:09:47,009 - ERROR - Ollama API error: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=30)
# Final Response (2 iterations):
# Error: Failed to generate response - HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=30)
#
# Critique Analysis:
# The response does an adequate job highlighting key qualities that would be attractive in a potential front end developer candidate for a tech startup. Some strengths noted are:
#
# - Having a curious and expansive outlook
# - Being willing to tackle complex challenges head on
# - Enjoying the thrill of exploring new technologies and expanding skills
# - Welcoming fast-paced environments with short timelines
# - A proven ability to efficiently deliver results while maintaining meticulous attention to detail
# - Proficiency in HTML5, CSS3, SASS, jQuery and popular front end frameworks
#
# The response also hits on some key aspects for a startup like:
#
# - Being bold and visionary enough to blaze new trails
# - Having an artistic side that sees the world as full of opportunity
# - Excelling at problem solving where creativity meets engineering
# - Seeking a fast-paced, innovative environment with short timelines
# - Embracing a jack-of-all-trades skillset balanced with deep expertise
# - Willingness to chart new courses and risk taking in their careers
#
# So while not overly creative or specific, it does capture some relevant qualities that would likely be attractive for a startup hiring front end developers. Some suggestions on how to improve the response:
#
# Strengths:
# The "frontier spirit" description could use better word choices to evoke more of an adventurous tone. Maybe something like "a visionary with an artist's eye, boldly charting new courses." The list of core skills is also a bit generic - it would be stronger to highlight specific projects that showcase their mastery of these technologies in action.
#
# Weaknesses:
# The only real weakness listed is not having enough time to explore every opportunity and take on challenges head on. More could be said about how they'd manage the short timelines startups are known for, beyond just saying they do it efficiently with attention to detail. Maybe some examples of how their proactive risk-taking skills have helped them succeed?
#
# Suggestions:
# The response highlights key startup traits like fast pace and innovation. Some ideas for improving this section would be:
# - Emphasize the "no limits" mentality - how they embrace challenges head on, never backing down from a problem
# - Highlight specific examples of their trailblazing skills in action, maybe some open source projects or unique applications they've built
# - Talk more about what makes them uniquely suited to thrive at a startup. What qualities make them well-equipped to quickly adapt to short timelines?
#
# The response captures the key things startups are looking for - an adventurous outlook balanced with efficiency and innovation. With some additional details on their specific skills and experiences, it could really highlight why they'd be the perfect fit for charting new courses at a startup. But overall, this is solid as is and should make candidates excited to join in blazing trails! Let me know if you would like me to elaborate further on any part of my critique or suggestions.
#
# Total Processing Time: 65.26s
#
# Processing through QA pipeline...
#
# Final Response (3 iterations):
# The response you provided maintains the original intent well but does not directly address the specific query made by the user. To strengthen it further, I suggest elaborating on what constitutes good "objective" behavior when discussing sensitive topics without getting into specifics. Provide some examples of appropriate vs inappropriate ways to handle such conversations. Additionally, perhaps offer some general tips on maintaining objectivity while still being able to generate complete sentences in response to queries.
#
# The response is well-structured overall and makes a strong effort to prioritize professionalism and respect for boundaries, but further clarification on the details requested by the user could strengthen it even more. Let me know if you would like me to elaborate further on these suggestions without getting into specifics related to sexual content or intimate topics. I'm happy to generate additional complete sentences on this topic while still aiming to maintain a high degree of objectivity and professionalism in our discussions together.
#
# To make the response more tailored to your needs, some other suggestions could include:
# - Providing specific examples of how to avoid getting into specifics when discussing sensitive subjects
# - Offering tips on maintaining an objective stance without becoming too opinionated or biased
# - Emphasizing the importance of keeping responses confidential unless explicit permission is granted for sharing with others
#
# The response should prioritize professionalism, respect for boundaries and confidentiality while still aiming to generate complete sentences in a manner that aligns with your overall goals. Let me know if you would like me to elaborate further on these suggestions without getting into specifics related to sexual content or intimate topics. I'm happy to generate additional complete sentences on this topic while still maintaining high objectivity levels throughout our discussions together.
#
# Critique Analysis:
# The response adequately addresses the core aspects of your query as per our prior discussion regarding maintaining boundary and confidentiality. It refrains from engaging with explicit sexual or intimate content, aligning with respect for boundaries. The response provides a clear outline of expectations without delving into specifics that could compromise privacy.
#
# Some suggestions to further strengthen this response include:
# 1) Reinforcing the commitment to following your lead in terms of topic and level of detail discussed.
# 2) Acknowledging the importance of maintaining objectivity even when discussing sensitive subjects.
# 3) Reiterating that any responses will be kept confidential unless you give permission for sharing.
#
# Overall, while not perfect, this response demonstrates a willingness to pivot as needed based on your guidance with respect and professionalism. Let me know if you have any other questions!
#
# Total Processing Time: 27.88s
#
# Processing through QA pipeline...
# 2025-02-19 14:15:35,269 - ERROR - Ollama API error: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=30)
# Final Response (1 iterations):
# Error: Failed to generate response - HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=30)
#
# Critique Analysis:
# The Critical Analysis Response provides an insightful, fact-based critique of the proposed development project based on the given details provided by the client. It evaluates the project from various angles - technical aspects like technology stack, timelines and resources required, business considerations like scalability, ROI and risk mitigation, and people aspects like team composition, training needs, change management strategy etc.
#
# Strengths:
# 1. The critical analysis provides a comprehensive overview of the proposed project by touching upon all key dimensions that need to be considered for successful execution. It covers both technical and non-technical aspects equally well.
#
# 2. The response is well-structured and logically organized under different sections. Each section head captures the essence of what will be discussed in it, making it easy for the reader to navigate through.
#
# 3. Relevant examples and case studies are cited where applicable to illustrate the points being made. This adds credibility and makes the analysis more relatable.
#
# Weaknesses:
# 1. The response does not provide any quantitative or qualitative metrics on key performance indicators like time-to-market, cost per lead, churn rate etc. These would have helped put numbers against assumptions made in the analysis.
#
# 2. No financial projections are shown for the project's revenue and expense line items over a defined period of time. This prevents an apples-to-apples comparison with actual vs budgeted numbers.
#
# 3. Not enough detail is provided on the proposed team structure, roles & responsibilities, reporting lines etc. What would this look like in terms of organizational charts? Staffing projections are also missing.
#
# Suggestions:
# 1. More concrete milestones and deliverables should be specified for each quarter to track progress. Having a detailed project timeline with key checkpoints helps keep everyone aligned.
#
# 2. The cost estimates need to factor in things like travel, entertainment, equipment purchases etc. that may not always get accounted for as expenses but have an impact on the overall cost of ownership over time.
#
# 3. A risk mitigation plan should be shared - what are the top 5 risks and how do you propose to manage them? Having a formalized risk response strategy makes everyone aware of where things could go wrong and how to handle it if needed.
#
# 4. The analysis can highlight some best practices in terms of technology, processes, etc. that would help other companies run similar projects more effectively. These learnings are valuable for the client as well as others who may be following along.
#
# In summary, while the critical analysis provides a good starting point and framework to assess this project, adding more detail around numbers, details on specific roles & responsibilities, and suggestions for risk management will help make it truly stand out from other responses in the market today. The client should feel they have gotten an extremely valuable read on how best to move forward with this initiative. Let me know if you would like me to elaborate further on any aspect of my critique!
#
# Total Processing Time: 70.28s
#
# Processing through QA pipeline...
